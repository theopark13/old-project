# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('WorldHappinessReportTotal.csv')

# %%
data
# Out:
#      Country name           Regional indicator  Year  Ladder score  \
# 0       Australia        North America and ANZ  2005      0.992010
# 1         Belgium               Western Europe  2005      0.904421
# 2          Brazil  Latin America and Caribbean  2005      0.211476
# 3          Canada        North America and ANZ  2005      1.077380
# 4         Czechia   Central and Eastern Europe  2005     -0.008048
# ...           ...                          ...   ...           ...
# 2093      Lesotho           Sub-Saharan Africa  2021     -1.888081
# 2094     Botswana           Sub-Saharan Africa  2021     -1.930125
# 2095       Rwanda           Sub-Saharan Africa  2021     -1.978709
# 2096     Zimbabwe           Sub-Saharan Africa  2021     -2.230971
# 2097  Afghanistan                   South Asia  2021     -2.812109
#
#       Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                  0.797846        0.854511                 0.983856
# ...

# %%
data[data['Country name']=='Singapore']['Perceptions of corruption']
# Out:
# 93           NaN
# 199    -4.404598
# 304    -3.677375
# 413    -3.787870
# 538    -3.727578
# 679    -3.526291
# 962    -2.966889
# 1104   -3.266957
# 1247   -3.270295
# 1391   -3.734819
# 1537   -3.094613
# 1680   -3.458325
# 1824   -3.526671
# 1980   -3.613457
# Name: Perceptions of corruption, dtype: float64

# %%
cols = data.columns[3:10]

# %%
cols
# Out:
# Index(['Ladder score', 'Logged GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
newdata = pd.DataFrame()
standard_scaler = StandardScaler()
for year in sorted(data['Year'].unique()):
    temp = data[data['Year'] == year]
    temp[cols] = standard_scaler.fit_transform(temp[cols])
    newdata = pd.concat([newdata, temp])
    
newdata
# Out:
# <ipython-input-7-b1a94412a404>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp[cols] = standard_scaler.fit_transform(temp[cols])
# c:\users\evfox\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py:1738: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
# <ipython-input-7-b1a94412a404>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data['Perceptions of corruption'] = - data['Perceptions of corruption']

# %%
data
# Out:
#      Country name           Regional indicator  Year  Ladder score  \
# 0       Australia        North America and ANZ  2005      0.992010
# 1         Belgium               Western Europe  2005      0.904421
# 2          Brazil  Latin America and Caribbean  2005      0.211476
# 3          Canada        North America and ANZ  2005      1.077380
# 4         Czechia   Central and Eastern Europe  2005     -0.008048
# ...           ...                          ...   ...           ...
# 2093      Lesotho           Sub-Saharan Africa  2021     -1.888081
# 2094     Botswana           Sub-Saharan Africa  2021     -1.930125
# 2095       Rwanda           Sub-Saharan Africa  2021     -1.978709
# 2096     Zimbabwe           Sub-Saharan Africa  2021     -2.230971
# 2097  Afghanistan                   South Asia  2021     -2.812109
#
#       Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                  0.797846        0.854511                 0.983856
# ...

# %%
for col in cols:
    data[f'{col} rank'] = data[col].rank(method='min', ascending=asc)

data
# Out:
# <ipython-input-32-989352187cd7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[f'{col} rank'] = data[col].rank(method='min', ascending=asc)
#     Country name  Regional indicator  Ladder score  Logged GDP per capita  \
# 0        Finland      Western Europe         7.842                 10.775
# 1        Denmark      Western Europe         7.620                 10.933
# 2    Switzerland      Western Europe         7.571                 11.117
# 3        Iceland      Western Europe         7.554                 10.878
# 4    Netherlands      Western Europe         7.464                 10.932
# ..           ...                 ...           ...                    ...
# ...

# %%
data.to_csv('WorldHappinessReportTotal.csv', index=False)
